# %% [markdown]
# ## Implementation of Feature Transform Suggested in EDA.ipynb

# %% [markdown]
# ## Imports and Reading in Relevant Data

# %%
import pandas as pd
import numpy as np

# %%
train = pd.read_csv("data/train.csv")
dev = pd.read_csv("data/dev.csv")

# %%
print(len(train))
train.head()
# Out:
# 250874
#    ex_id  user_id  prod_id  rating  label        date  \
# 0      0      923        0     3.0      1  2014-12-08
# 1      1      924        0     3.0      1  2013-05-16
# 2      2      925        0     4.0      1  2013-07-01
# 3      3      926        0     4.0      1  2011-07-28
# 4      4      927        0     4.0      1  2010-11-01
#
#                                               review
# 0  The food at snack is a selection of popular Gr...
# 1  This little place in Soho is wonderful. I had ...
# 2  ordered lunch for 15 from Snack last Friday.  ...
# 3  This is a beautiful quaint little restaurant o...
# 4  Snack is great place for a  casual sit down lu...

# %%
print(len(dev))
dev.tail()
# Out:
# 35918
#         ex_id  user_id  prod_id  rating  label        date  \
# 35913  358855   161115      349     3.0      0  2014-12-15
# 35914  358859   161116      349     2.0      0  2014-12-10
# 35915  358884   161125      349     5.0      0  2014-09-05
# 35916  358894     1423      349     5.0      0  2014-07-13
# 35917  358935   161140      349     5.0      0  2014-03-04
#
#                                                   review
# 35913  Okay, so I gotta repeat the chorus here and st...
# 35914  The pizza is delicious, but it's SO loud here,...
# 35915  Emily has hands down the best pizza I've had i...
# 35916  I'm not entirely sure who came up with the nam...
# 35917  My date and I had an amazing time here.  The s...

# %% [markdown]
# ## Combining the Data

# %% [markdown]
# Because there is overlap between users in train and dev, the datasets must be combined to properly implement a <i> reviewsToDate </i> column. If a user shows up in both sets, we don't want to re-increment the # of reviews we've seen up to the date of the new instance in the dev set. Once the transformation is complete, the combined dataset will be split back into train and dev, since the <i> ex_id </i> column is unique across the concatenation of the datasets.

# %%
train_ex = list(train.ex_id)
dev_ex = list(dev.ex_id)

# %%
combined = pd.concat([train,dev],axis=0)

# %%
combined.head()
# Out:
#    ex_id  user_id  prod_id  rating  label        date  \
# 0      0      923        0     3.0      1  2014-12-08
# 1      1      924        0     3.0      1  2013-05-16
# 2      2      925        0     4.0      1  2013-07-01
# 3      3      926        0     4.0      1  2011-07-28
# 4      4      927        0     4.0      1  2010-11-01
#
#                                               review
# 0  The food at snack is a selection of popular Gr...
# 1  This little place in Soho is wonderful. I had ...
# 2  ordered lunch for 15 from Snack last Friday.  ...
# 3  This is a beautiful quaint little restaurant o...
# 4  Snack is great place for a  casual sit down lu...

# %%
combined.tail()
# Out:
#         ex_id  user_id  prod_id  rating  label        date  \
# 35913  358855   161115      349     3.0      0  2014-12-15
# 35914  358859   161116      349     2.0      0  2014-12-10
# 35915  358884   161125      349     5.0      0  2014-09-05
# 35916  358894     1423      349     5.0      0  2014-07-13
# 35917  358935   161140      349     5.0      0  2014-03-04
#
#                                                   review
# 35913  Okay, so I gotta repeat the chorus here and st...
# 35914  The pizza is delicious, but it's SO loud here,...
# 35915  Emily has hands down the best pizza I've had i...
# 35916  I'm not entirely sure who came up with the nam...
# 35917  My date and I had an amazing time here.  The s...

# %%
len(combined) == (len(train)+len(dev))
# Out:
# True

# %% [markdown]
# ## Implementation

# %%
copy = combined.copy()
copy.head()
# Out:
#    ex_id  user_id  prod_id  rating  label        date  \
# 0      0      923        0     3.0      1  2014-12-08
# 1      1      924        0     3.0      1  2013-05-16
# 2      2      925        0     4.0      1  2013-07-01
# 3      3      926        0     4.0      1  2011-07-28
# 4      4      927        0     4.0      1  2010-11-01
#
#                                               review
# 0  The food at snack is a selection of popular Gr...
# 1  This little place in Soho is wonderful. I had ...
# 2  ordered lunch for 15 from Snack last Friday.  ...
# 3  This is a beautiful quaint little restaurant o...
# 4  Snack is great place for a  casual sit down lu...

# %%
copy.tail()
# Out:
#         ex_id  user_id  prod_id  rating  label        date  \
# 35913  358855   161115      349     3.0      0  2014-12-15
# 35914  358859   161116      349     2.0      0  2014-12-10
# 35915  358884   161125      349     5.0      0  2014-09-05
# 35916  358894     1423      349     5.0      0  2014-07-13
# 35917  358935   161140      349     5.0      0  2014-03-04
#
#                                                   review
# 35913  Okay, so I gotta repeat the chorus here and st...
# 35914  The pizza is delicious, but it's SO loud here,...
# 35915  Emily has hands down the best pizza I've had i...
# 35916  I'm not entirely sure who came up with the nam...
# 35917  My date and I had an amazing time here.  The s...

# %%
def engineered_df(df):
    rolling_rev = []
    user_dict = {}
    for index,row in df.iterrows():
        curr_date = row['date']
        curr_user = row['user_id']
        
        if(curr_user not in user_dict):
            dates = df.loc[df.user_id == curr_user,'date'].tolist()
            dates.sort()
            user_dict[curr_user] = dates
        index = user_dict[curr_user].index(curr_date)
        
        rolling_rev.append(index)
        
    df['reviewsToDate'] = rolling_rev
    return df

# %% [markdown]
# Now the combined dataset will get passed in to the engineered_df function, and a new df will be returned. We then use the ex_id column to split back into train and test

# %%
combined = engineered_df(combined)

# %% [markdown]
# ### Sanity Check

# %% [markdown]
# We will pull a user with multiple reviews from both the first 10 and last 10 rows of the transformed dataframe, and check the original combined dataframe to esnure both the # of reviews match and the ordering is correct.

# %%
combined.head(10)
# Out:
#    ex_id  user_id  prod_id  rating  label        date  \
# 0      0      923        0     3.0      1  2014-12-08
# 1      1      924        0     3.0      1  2013-05-16
# 2      2      925        0     4.0      1  2013-07-01
# 3      3      926        0     4.0      1  2011-07-28
# 4      4      927        0     4.0      1  2010-11-01
# 5      5      928        0     4.0      1  2009-09-02
# 6      7      930        0     4.0      1  2007-05-20
# 7      8      931        0     4.0      1  2005-12-27
# 8     10      933        0     5.0      1  2014-01-21
# 9     12      935        0     5.0      1  2011-01-31
#
#                                               review  reviewsToDate
# 0  The food at snack is a selection of popular Gr...             29
# 1  This little place in Soho is wonderful. I had ...              0
# 2  ordered lunch for 15 from Snack last Friday.  ...              0
# 3  This is a beautiful quaint little restaurant o...              0
# 4  Snack is great place for a  casual sit down lu...              1
# 5  A solid 4 stars for this greek food spot.  If ...              0
# 6  Love this place!  Try the Chicken sandwich or ...              0
# 7  My friend and I were intrigued by the nightly ...             15
# 8        pretty cool place...good food...good people              0
# 9  Fabulous Authentic Greek Food!!! This little s...              0

# %%
print(len(copy[copy['user_id']==923].sort_values(by=['date'])))
copy[copy['user_id']==923].sort_values(by=['date'])
# Out:
# 31
#          ex_id  user_id  prod_id  rating  label        date  \
# 202384  289603      923      759     5.0      1  2013-11-04
# 122365  174979      923      131     5.0      1  2013-11-11
# 166153  237627      923      622     5.0      1  2013-11-19
# 172282  246460      923      906     5.0      1  2013-11-19
# 9044     90566      923      256     5.0      1  2013-12-08
# 129686  185412      923      505     5.0      1  2014-01-04
# 81951   117298      923      675     5.0      1  2014-01-04
# 4180      5992      923       19     5.0      1  2014-01-14
# 34295   342904      923      919     5.0      1  2014-02-02
# 29808   297788      923      778     5.0      1  2014-02-12
# 50805    72648      923      649     5.0      1  2014-02-12
# 128545  183766      923      502     5.0      1  2014-02-12
# 182849  261658      923      337     5.0      1  2014-02-18
# 29356    41894      923      100     4.0      1  2014-03-05
# 37708    53903      923      133     5.0      1  2014-03-05
# 204847  293098      923      741     5.0      1  2014-03-05
# 20800    29654      923       79     3.0      1  2014-03-30
# 9072     12853      923       40     4.0      1  2014-05-30
# 35414   353769      923      908     4.0      1  2014-06-12
# 34638   346277      923      247     1.0      1  2014-07-07
# 95818   137121      923      400     5.0      1  2014-07-07
# 90666   129738      923      376     4.0      1  2014-07-07
# 31815    45404      923      103     5.0      1  2014-07-28
# 136094  194629      923      420     5.0      1  2014-08-25
# 21641    30833      923       81     4.0      1  2014-09-28
# 190430  272462      923      710     4.0      1  2014-10-07
# 152833  218543      923      572     4.0      1  2014-10-07
# 113143  161807      923      456     4.0      1  2014-11-13
# 42090    60145      923      152     5.0      1  2014-11-13
# 232937  333266      923      880     3.0      1  2014-12-08
# 0            0      923        0     3.0      1  2014-12-08
#
#                                                    review
# 202384  The falafel were superb, stuffed grape leaved ...
# 122365  The food is simply excellent. Everything is as...
# 166153  This place is amazing.We really love good lati...
# 172282  I had Nasi Lemak and Nyonya Seafood Fried Rice...
# 9044    This is the place to go if u love tofu, kimchi...
# 129686  I was in the neighborhood with out-of-town gue...
# 81951   I recently ate at Olea again and continue to b...
# 4180    The restaurant is on the ground floor of a typ...
# 34295   Bistango is a casual trattoria that hits all t...
# 29808   The place is hard to find and out of the way, ...
# 50805   This restaurant was quite a pleasant surprise....
# 128545  The crab and pork noodles is delicious!!! I re...
# 182849  My husband and I went to this restaurant for a...
# 29356   Clinton street baking is a super popular baker...
# 37708   The Tom's Restaurant is the outside shot of th...
# 204847  This is a super little spot for brunch. Quaint...
# 20800   We ate at the Blue Ribbon with colleagues. The...
# 9072    Really nice mousaka and lovely décor inside. A...
# 35414   Great dinner with great service. Party of elev...
# 34638   Their ramen is very mediocre, we are living in...
# 95818   This place has amazing tacos. The sopes are pr...
# 90666   I always visit if in the mood for a hearty Pol...
# 31815   Thiru has wonderful personality. He has a very...
# 136094  We had a lovely meal on a Friday night at Marc...
# 21641   I loved the antibiotic- and hormone-free chick...
# 190430  The Post Office is a friendly place. The staff...
# 152833  Tried the huge slices with some of my friends ...
# 113143  Basso56 was very crowded with the theatre crow...
# 42090   Great food and wine! Waitress was super helpfu...
# 232937  Salads are good. Prices are good. Pesto lasagn...
# 0       The food at snack is a selection of popular Gr...

# %%
combined.tail(10)
# Out:
#         ex_id  user_id  prod_id  rating  label        date  \
# 35908  358813    18011      921     4.0      0  2012-09-30
# 35909  358827     2230      921     5.0      0  2012-06-08
# 35910  358840     3504      921     5.0      0  2012-01-25
# 35911  358841    45596      921     5.0      0  2012-01-18
# 35912  358850   161112      349     3.0      1  2014-04-09
# 35913  358855   161115      349     3.0      0  2014-12-15
# 35914  358859   161116      349     2.0      0  2014-12-10
# 35915  358884   161125      349     5.0      0  2014-09-05
# 35916  358894     1423      349     5.0      0  2014-07-13
# 35917  358935   161140      349     5.0      0  2014-03-04
#
#                                                   review  reviewsToDate
# 35908  This review is only for their Happy Hour.  2 f...             12
# 35909  The cat's out of the bag! Bijan's is no longer...              2
# 35910  Ever since Bijan's opened up, happy days are h...             73
# 35911  This is my new favorite neighborhood bar.  I w...              0
# 35912  The staff was incredibly nice, the lemonade ta...              0
# 35913  Okay, so I gotta repeat the chorus here and st...              0
# 35914  The pizza is delicious, but it's SO loud here,...              0
# 35915  Emily has hands down the best pizza I've had i...              0
# 35916  I'm not entirely sure who came up with the nam...             17
# 35917  My date and I had an amazing time here.  The s...              0

# %%
copy[copy['user_id']==1423].sort_values(by=['date'])
# Out:
#          ex_id  user_id  prod_id  rating  label        date  \
# 183324  262316     1423      676     5.0      0  2012-07-30
# 124704  178341     1423      484     5.0      0  2012-07-31
# 94940   135856     1423      396     5.0      0  2012-10-18
# 83236   119109     1423      345     5.0      0  2012-12-21
# 12577    17873     1423      336     4.0      0  2013-07-19
# 106664  152607     1423      440     5.0      0  2013-09-03
# 51302    73348     1423      203     4.0      0  2013-10-15
# 188887  270270     1423      702     4.0      0  2013-10-29
# 92393   132165     1423      628     5.0      0  2013-10-29
# 215812  308767     1423      803     3.0      0  2013-11-08
# 113975  163017     1423       23     4.0      0  2014-01-27
# 227003  324754     1423      857     5.0      0  2014-04-27
# 374        501     1423        3     5.0      0  2014-05-04
# 81775   117036     1423      339     5.0      0  2014-05-18
# 43886    62753     1423      164     5.0      0  2014-06-22
# 234104  334932     1423      685     3.0      0  2014-06-22
# 219877  314607     1423      831     4.0      0  2014-07-03
# 35916   358894     1423      349     5.0      0  2014-07-13
# 40967    58522     1423      145     4.0      0  2014-07-27
# 86642   123994     1423      362     4.0      0  2014-09-07
# 25091    35856     1423       91     4.0      0  2014-09-07
# 181457  259671     1423      670     5.0      0  2014-09-21
#
#                                                    review
# 183324  Lovely location near Battery Park and the near...
# 124704  &%@#! There's not a damn thing about this plac...
# 94940   Unless you're crazy allergic to seafood (or ju...
# 83236   I have to admit some shame in passing some und...
# 12577   Stumbled upon this restaurant after a long, he...
# 106664  With the constant debates about the best ramen...
# 51302   I'm still dreaming of my visit at Little Colli...
# 188887  Excellent Thai food in the Cobble Hill area, w...
# 92393   I professed my love for a well-known hipster B...
# 215812  Anella definitely caught my attention with its...
# 113975  Unlike the other restaurants and bars that cat...
# 227003  Peaches Hothouse is now one of my top choices ...
# 374     Dekalb Restaurant is a neighbourhood gem that ...
# 81775   This weekend my friends and I stopped at Samur...
# 43886   Even though Barn Joo is practically across the...
# 234104  My friends and I stopped by Umami Burger for a...
# 219877  My friends and I came to the Shakespeare for d...
# 35916   I'm not entirely sure who came up with the nam...
# 40967   Our friends and I came to Table 87 yesterday t...
# 86642   It's probably for the best that Hometown is so...
# 25091   When it comes to potatoes, I was Irish in a pa...
# 181457  My bf and I initially stumbled upon Thelma on ...

# %% [markdown]
# ### Splitting Data Back

# %%
train = combined[combined['ex_id'].isin(train_ex)]
print(len(train))
train.head()
# Out:
# 250874
#    ex_id  user_id  prod_id  rating  label        date  \
# 0      0      923        0     3.0      1  2014-12-08
# 1      1      924        0     3.0      1  2013-05-16
# 2      2      925        0     4.0      1  2013-07-01
# 3      3      926        0     4.0      1  2011-07-28
# 4      4      927        0     4.0      1  2010-11-01
#
#                                               review  reviewsToDate
# 0  The food at snack is a selection of popular Gr...             29
# 1  This little place in Soho is wonderful. I had ...              0
# 2  ordered lunch for 15 from Snack last Friday.  ...              0
# 3  This is a beautiful quaint little restaurant o...              0
# 4  Snack is great place for a  casual sit down lu...              1

# %%
dev = combined[combined['ex_id'].isin(dev_ex)]
print(len(dev))
dev.head()
# Out:
# 35918
#    ex_id  user_id  prod_id  rating  label        date  \
# 0     11      934        0     5.0      1  2014-01-20
# 1     17      940        0     4.0      0  2014-09-16
# 2     20      943        0     5.0      0  2014-05-24
# 3     30      953        0     4.0      0  2013-10-17
# 4     43      966        0     3.0      0  2012-12-19
#
#                                               review  reviewsToDate
# 0  all around good place, cozy, I came in and did...              0
# 1  For lunch, my friend and I had: -Lamb sandwich...              7
# 2  Some good Big Greek cooking!! Came to City on ...              0
# 3  So... as you may notice from some of my other ...              3
# 4  I don't understand the whole "You can't order ...             16

# %% [markdown]
# ### Exporting Transformed Column

# %%
import pickle
with open('data/train_reviews_ToDate.pckl', 'wb') as f:
    pickle.dump(train['reviewsToDate'], f)
    
with open('data/dev_reviewsToDate.pckl', 'wb') as f:
    pickle.dump(dev['reviewsToDate'], f)
